# %%
import math
import numpy as np

# %%
def leibniz(n):
    calc_pi = 
    for i in range(n):
        calc_pi += pow(-1,i)/(2*i+1)
        
    return calc_pi * 4

# %%
leibniz(100)
# Out:
# 3.1315929035585537

# %%
for i in range(0,5000):
    calc_pi = leibniz(i)
    error = abs(np.pi - calc_pi)
    
    if i % 100 == 0:
        print(error)
# Out:
# 3.141592653589793
# 0.00999975003123943
# 0.004999968750976969
# 0.0033333240742017267
# 0.0024999960937788224
# 0.001999998000008052
# 0.0016666655092620886
# 0.0014285706997085867
# 0.0012499995117174478
# 0.0011111107681749388
# 0.000999999749998981
# 0.0009090907212607746
# 0.0008333331886558604
# 0.0007692306554392125
# 0.0007142856231787675
# 0.0006666665925938453
# 0.0006249999389646987
# 0.0005882352432333704
# 0.0005555555126903755
# 0.0005263157530279727
# 0.0004999999687518297
# 0.00047619044919544606
# 0.0004545454310660446
# 0.00043478258814921844
# 0.0004166666485820869
# 0.0003999999839994217
# 0.0003846153703910282
# 0.00037037035766696036
# 0.0003571428457527226
# 0.00034482757595410973
# 0.0003333333240744807
# 0.0003225806367699313
# 0.000312499992369375
# 0.0003030302960720377
# 0.00029411764069475765
# 0.00028571427987955644
# 0.0002777777724145558
# 0.00027027026532966403
# 0.0002631578901759468
# 0.00025641025219069746
# 0.0002499999960887678
# ...

# %%
import numpy as np
import time

# %%
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    
    for k in range(max_iterations):
        x_new = x.copy()
        
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
            
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# %%
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i] 
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# %%
A = np.array([[10, -1, 2, 0, 0],
              [-1, 11, -1,3, 0],
              [2, -1, 10, -1, 0],
              [0, 3, -1, 8, -2],
              [0, 0, 0, -2, 9 ]], dtype = float)

b = np.array([14, 30, 26, 25, 37], dtype = float)

x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 10000


x = np.linalg.solve(A, b)
print("Regular Solve: ", x)
# Out:
# Regular Solve:  [1. 2. 3. 4. 5.]

# %%
start_time = time.perf_counter()
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
end_time = time.perf_counter()
elapsed_time = end_time - start_time
print(f"Jacobi Solution: {solution}")
print(f"Iterations: {iterations}")
print("Elapsed Time: " , elapsed_time)
# Out:
# Jacobi Solution: [0.99999995 2.00000025 2.99999986 4.00000008 4.99999983]
# Iterations: 18
# Elapsed Time:  0.0013116048648953438

# %%
start_time = time.perf_counter()
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
end_time = time.perf_counter()
elapsed_time = end_time - start_time
print(f"Gauss-Seidel Solution: {solution}")
print(f"Iterations: {iterations}")
print("Elapsed Time: " , elapsed_time)
# Out:
# Gauss-Seidel Solution: [1.00000003 2.00000002 2.99999999 3.99999998 5.        ]
# Iterations: 10
# Elapsed Time:  0.000791626051068306

# %%
A = np.array([[1,2,3,0,0],
               [2,1,2,3,0],
               [3,2,1,2,3],
               [0,3,2,1,2],
               [0,0,3,2,1]], dtype=float)
b = np.array([14,22,33,26,22], dtype=float)

x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 10000


x = np.linalg.solve(A, b)
print("Regular Solve: ", x)
# Out:
# Regular Solve:  [1. 2. 3. 4. 5.]

# %%
start_time = time.perf_counter()
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
end_time = time.perf_counter()
elapsed_time = end_time - start_time
print(f"Jacobi Solution: {solution}")
print(f"Iterations: {iterations}")
print("Elapsed Time: " , elapsed_time)
# Out:
# <ipython-input-3-820dd4969727>:7: RuntimeWarning: overflow encountered in double_scalars
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)
# <ipython-input-3-820dd4969727>:7: RuntimeWarning: invalid value encountered in double_scalars
#   s = sum(A[i][j] * x[j] for j in range(n) if j != i)
# Jacobi Solution: [nan nan nan nan nan]
# Iterations: 10000
# Elapsed Time:  0.5296315457671881

# %%
start_time = time.perf_counter()
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
end_time = time.perf_counter()
elapsed_time = end_time - start_time
print(f"Gauss-Seidel Solution: {solution}")
print(f"Iterations: {iterations}")
print("Elapsed Time: " , elapsed_time)
# Out:
# <ipython-input-2-1e3c8a0f5b36>:9: RuntimeWarning: overflow encountered in double_scalars
#   s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
# <ipython-input-2-1e3c8a0f5b36>:10: RuntimeWarning: overflow encountered in double_scalars
#   s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
# <ipython-input-2-1e3c8a0f5b36>:10: RuntimeWarning: invalid value encountered in double_scalars
#   s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
# Gauss-Seidel Solution: [nan nan nan nan nan]
# Iterations: 10000
# Elapsed Time:  0.41522124875336885

# %% [markdown]
# For challenge 6A, Gauss–Seidel converges almost twice as fast (fewer iterations).
# For challenge 6B, matrix is not diagonally dominant, so convergence is not guaranteed.
